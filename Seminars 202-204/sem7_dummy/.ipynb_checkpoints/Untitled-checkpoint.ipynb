# %%
dataFrame <- read.csv("hsb2.csv")

# %%
dataFrame
# Out:
#     id  female race ses schtyp prog read write math science socst Dum1 Dum2
# 1    70 0      4    1   1      1    57   52    41   47      57    0    0
# 2   121 1      4    2   1      3    68   59    53   63      61    0    0
# 3    86 0      4    3   1      1    44   33    54   58      31    0    0
# 4   141 0      4    3   1      3    63   44    47   53      56    0    0
# 5   172 0      4    2   1      2    47   52    57   53      61    0    0
# 6   113 0      4    2   1      2    44   52    51   63      61    0    0
# 7    50 0      3    2   1      1    50   59    42   53      61    0    1
# 8    11 0      1    2   1      2    34   46    45   39      36    0    0
# 9    84 0      4    2   1      1    63   57    54   58      51    0    0
# 10   48 0      3    2   1      2    57   55    52   50      51    0    1
# 11   75 0      4    2   1      3    60   46    51   53      61    0    0
# 12   60 0      4    2   1      2    57   65    51   63      61    0    0
# 13   95 0      4    3   1      2    73   60    71   61      71    0    0
# 14  104 0      4    3   1      2    54   63    57   55      46    0    0
# 15   38 0      3    1   1      2    45   57    50   31      56    0    1
# 16  115 0      4    1   1      1    42   49    43   50      56    0    0
# 17   76 0      4    3   1      2    47   52    51   50      56    0    0
# 18  195 0      4    2   2      1    57   57    60   58      56    0    0
# 19  114 0      4    3   1      2    68   65    62   55      61    0    0
# 20   85 0      4    2   1      1    55   39    57   53      46    0    0
# 21  167 0      4    2   1      1    63   49    35   66      41    0    0
# 22  143 0      4    2   1      3    63   63    75   72      66    0    0
# 23   41 0      3    2   1      2    50   40    45   55      56    0    1
# 24   20 0      1    3   1      2    60   52    57   61      61    0    0
# 25   12 0      1    2   1      3    37   44    45   39      46    0    0
# 26   53 0      3    2   1      3    34   37    46   39      31    0    1
# 27  154 0      4    3   1      2    65   65    66   61      66    0    0
# 28  178 0      4    2   2      3    47   57    57   58      46    0    0
# 29  196 0      4    3   2      2    44   38    49   39      46    0    0
# 30   29 0      2    1   1      1    52   44    49   55      41    1    0
# ⋮   ⋮   ⋮      ⋮    ⋮   ⋮      ⋮    ⋮    ⋮     ⋮    ⋮       ⋮     ⋮    ⋮
# 171 119 1      4    1   1      1    42   57    45   50      43    0    0
# 172  13 1      1    2   1      3    47   46    39   47      61    0    0
# 173  51 1      3    3   1      1    42   36    42   31      39    0    1
# 174  26 1      2    3   1      2    60   59    62   61      51    1    0
# 175  36 1      3    1   1      1    44   49    44   35      51    0    1
# 176 135 1      4    1   1      2    63   60    65   54      66    0    0
# 177  59 1      4    2   1      2    65   67    63   55      71    0    0
# 178  78 1      4    2   1      2    39   54    54   53      41    0    0
# 179  64 1      4    3   1      3    50   52    45   58      36    0    0
# 180  63 1      4    1   1      1    52   65    60   56      51    0    0
# 181  79 1      4    2   1      2    60   62    49   50      51    0    0
# 182 193 1      4    2   2      2    44   49    48   39      51    0    0
# 183  92 1      4    3   1      1    52   67    57   63      61    0    0
# 184 160 1      4    2   1      2    55   65    55   50      61    0    0
# 185  32 1      2    3   1      3    50   67    66   66      56    1    0
# 186  23 1      2    1   1      2    65   65    64   58      71    1    0
# 187 158 1      4    2   1      1    52   54    55   53      51    0    0
# 188  25 1      2    2   1      1    47   44    42   42      36    1    0
# 189 188 1      4    3   2      2    63   62    56   55      61    0    0
# 190  52 1      3    1   1      2    50   46    53   53      66    0    1
# 191 124 1      4    1   1      3    42   54    41   42      41    0    0
# 192 175 1      4    3   2      1    36   57    42   50      41    0    0
# 193 184 1      4    2   2      3    50   52    53   55      56    0    0
# 194  30 1      2    3   1      2    41   59    42   34      51    1    0
# 195 179 1      4    2   2      2    47   65    60   50      56    0    0
# 196  31 1      2    2   2      1    55   59    52   42      56    1    0
# 197 145 1      4    2   1      3    42   46    38   36      46    0    0
# 198 187 1      4    2   2      1    57   41    57   55      52    0    0
# 199 118 1      4    2   1      1    55   62    58   58      61    0    0
# 200 137 1      4    3   1      2    63   65    65   53      61    0    0
#     Dum3
# 1   1
# 2   1
# 3   1
# 4   1
# 5   1
# 6   1
# 7   0
# 8   0
# 9   1
# 10  0
# 11  1
# 12  1
# 13  1
# 14  1
# 15  0
# 16  1
# 17  1
# 18  1
# 19  1
# 20  1
# 21  1
# 22  1
# 23  0
# 24  0
# 25  0
# 26  0
# 27  1
# 28  1
# 29  1
# 30  0
# ⋮   ⋮
# 171 1
# 172 0
# 173 0
# 174 0
# 175 0
# 176 1
# 177 1
# 178 1
# 179 1
# 180 1
# 181 1
# 182 1
# 183 1
# 184 1
# 185 0
# 186 0
# 187 1
# 188 0
# 189 1
# 190 0
# 191 1
# 192 1
# 193 1
# 194 0
# 195 1
# 196 0
# 197 1
# 198 1
# 199 1
# 200 1

# %%
dataFrame$Dum1 <- as.numeric(dataFrame$race== 2)
dataFrame$Dum2 <- as.numeric(dataFrame$race== 3)
dataFrame$Dum3 <- as.numeric(dataFrame$race== 4)

# %%
fit <- lm(write ~ Dum1 + Dum2 + Dum3, data=dataFrame)
summary(fit)
# Out:
# Call:
# lm(formula = write ~ Dum1 + Dum2 + Dum3, data = dataFrame)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -23.0552  -5.4583   0.9724   7.0000  18.8000
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   46.458      1.842  25.218  < 2e-16 ***
# Dum1          11.542      3.286   3.512 0.000552 ***
# Dum2           1.742      2.732   0.637 0.524613
# Dum3           7.597      1.989   3.820 0.000179 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 9.025 on 196 degrees of freedom
# Multiple R-squared:  0.1071,	Adjusted R-squared:  0.0934
# F-statistic: 7.833 on 3 and 196 DF,  p-value: 5.785e-05

# %%
fit1 <- lm(write ~ factor(race), data=dataFrame)
summary(fit1)
# Out:
# Call:
# lm(formula = write ~ factor(race), data = dataFrame)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -23.0552  -5.4583   0.9724   7.0000  18.8000
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)     46.458      1.842  25.218  < 2e-16 ***
# factor(race)2   11.542      3.286   3.512 0.000552 ***
# factor(race)3    1.742      2.732   0.637 0.524613
# factor(race)4    7.597      1.989   3.820 0.000179 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 9.025 on 196 degrees of freedom
# Multiple R-squared:  0.1071,	Adjusted R-squared:  0.0934
# F-statistic: 7.833 on 3 and 196 DF,  p-value: 5.785e-05

# %%
fit1 <- lm(write ~  female + factor(race) + factor(ses)+factor(schtyp)+factor(prog)+read+math+science+socst, data=dataFrame)
summary(fit1)
# Out:
# Call:
# lm(formula = write ~ female + factor(race) + factor(ses) + factor(schtyp) +
#     factor(prog) + read + math + science + socst, data = dataFrame)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -16.1467  -3.8527   0.1007   3.6488  15.7214
#
# Coefficients:
#                 Estimate Std. Error t value Pr(>|t|)
# (Intercept)      8.00608    3.36183   2.381 0.018253 *
# female           5.09866    0.89044   5.726 4.07e-08 ***
# factor(race)2    5.45896    2.29204   2.382 0.018242 *
# factor(race)3    0.89817    1.85115   0.485 0.628109
# factor(race)4    1.59622    1.41901   1.125 0.262089
# factor(ses)2    -1.25317    1.17559  -1.066 0.287809
# factor(ses)3    -1.11240    1.33044  -0.836 0.404163
# factor(schtyp)2  1.15181    1.21645   0.947 0.344936
# factor(prog)2    1.37875    1.19282   1.156 0.249215
# factor(prog)3   -0.27264    1.31233  -0.208 0.835647
# read             0.11617    0.06535   1.778 0.077113 .
# math             0.17451    0.07131   2.447 0.015331 *
# science          0.25560    0.06482   3.943 0.000114 ***
# socst            0.22924    0.05557   4.125 5.58e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 6.028 on 186 degrees of freedom
# Multiple R-squared:  0.622,	Adjusted R-squared:  0.5956
# F-statistic: 23.54 on 13 and 186 DF,  p-value: < 2.2e-16

# %%
fit1 <- lm(math ~  female + factor(race) + factor(ses)+factor(schtyp)+factor(prog) +read+science+socst + write, data=dataFrame)
summary(fit1)
# Out:
# Call:
# lm(formula = math ~ female + factor(race) + factor(ses) + factor(schtyp) +
#     factor(prog) + socst + read + science + socst + write, data = dataFrame)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -20.9797  -3.8752  -0.1873   4.3754  14.7336
#
# Coefficients:
#                 Estimate Std. Error t value Pr(>|t|)
# (Intercept)     12.28495    3.33413   3.685 0.000300 ***
# female          -0.74933    0.97578  -0.768 0.443505
# factor(race)2    4.67399    2.32959   2.006 0.046267 *
# factor(race)3   -0.18131    1.87451  -0.097 0.923051
# factor(race)4    0.59908    1.44025   0.416 0.677924
# factor(ses)2     0.27596    1.19316   0.231 0.817348
# factor(ses)3     0.09402    1.34893   0.070 0.944505
# factor(schtyp)2 -0.26205    1.23386  -0.212 0.832045
# factor(prog)2    3.84927    1.17813   3.267 0.001293 **
# factor(prog)3    0.01005    1.32824   0.008 0.993970
# socst            0.05746    0.05860   0.980 0.328118
# read             0.22042    0.06471   3.406 0.000807 ***
# science          0.27000    0.06535   4.132 5.44e-05 ***
# write            0.17873    0.07304   2.447 0.015331 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 6.1 on 186 degrees of freedom
# Multiple R-squared:  0.6037,	Adjusted R-squared:  0.576
# F-statistic:  21.8 on 13 and 186 DF,  p-value: < 2.2e-16

# %%
fit1 <- lm(science  ~  female + factor(race) + factor(ses)+factor(schtyp)+factor(prog)+socst +read+ math + write, data=dataFrame)
summary(fit1)
# Out:
# Call:
# lm(formula = science ~ female + factor(race) + factor(ses) +
#     factor(schtyp) + factor(prog) + socst + read + math + write,
#     data = dataFrame)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -17.0778  -4.0218  -0.0648   3.8939  21.0543
#
# Coefficients:
#                 Estimate Std. Error t value Pr(>|t|)
# (Intercept)      9.20562    3.64668   2.524 0.012426 *
# female          -3.09689    1.02462  -3.022 0.002861 **
# factor(race)2   -1.23363    2.52687  -0.488 0.625980
# factor(race)3   -2.35134    2.00555  -1.172 0.242529
# factor(race)4    2.89012    1.53271   1.886 0.060905 .
# factor(ses)2     0.67696    1.28047   0.529 0.597657
# factor(ses)3     1.26525    1.44555   0.875 0.382557
# factor(schtyp)2 -0.59886    1.32438  -0.452 0.651667
# factor(prog)2   -4.06618    1.26627  -3.211 0.001558 **
# factor(prog)3   -1.97097    1.41895  -1.389 0.166483
# socst           -0.01508    0.06308  -0.239 0.811340
# read             0.24976    0.06924   3.607 0.000398 ***
# math             0.31133    0.07535   4.132 5.44e-05 ***
# write            0.30185    0.07655   3.943 0.000114 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 6.55 on 186 degrees of freedom
# Multiple R-squared:  0.5909,	Adjusted R-squared:  0.5623
# F-statistic: 20.66 on 13 and 186 DF,  p-value: < 2.2e-16

# %%
fit1 <- lm(socst   ~  female + factor(race) + factor(ses)+factor(schtyp)+factor(prog)+science +read+ math + write, data=dataFrame)
summary(fit1)
# Out:
# Call:
# lm(formula = socst ~ female + factor(race) + factor(ses) + factor(schtyp) +
#     factor(prog) + science + read + math + write, data = dataFrame)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -24.274  -4.497   0.878   5.204  16.145
#
# Coefficients:
#                 Estimate Std. Error t value Pr(>|t|)
# (Intercept)     10.91272    4.23505   2.577  0.01075 *
# female           0.32359    1.21942   0.265  0.79103
# factor(race)2   -5.06522    2.91492  -1.738  0.08392 .
# factor(race)3    1.38331    2.33714   0.592  0.55465
# factor(race)4   -1.03383    1.79659  -0.575  0.56569
# factor(ses)2     3.86620    1.46198   2.644  0.00888 **
# factor(ses)3     4.80444    1.64613   2.919  0.00395 **
# factor(schtyp)2 -1.11553    1.53781  -0.725  0.46912
# factor(prog)2    0.83704    1.51059   0.554  0.58017
# factor(prog)3   -3.45020    1.63814  -2.106  0.03653 *
# science         -0.02037    0.08520  -0.239  0.81134
# read             0.31833    0.07990   3.984 9.71e-05 ***
# math             0.08949    0.09127   0.980  0.32812
# write            0.36563    0.08864   4.125 5.58e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 7.613 on 186 degrees of freedom
# Multiple R-squared:  0.5301,	Adjusted R-squared:  0.4972
# F-statistic: 16.14 on 13 and 186 DF,  p-value: < 2.2e-16

# %%
fit1 <- lm(read    ~  female + factor(race) + factor(ses)+factor(schtyp)+factor(prog)+science + math + socst + write, data=dataFrame)
summary(fit1)
# Out:
# Call:
# lm(formula = read ~ female + factor(race) + factor(ses) + factor(schtyp) +
#     factor(prog) + science + math + socst + write, data = dataFrame)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -18.6653  -4.2563  -0.0036   4.6346  15.7299
#
# Coefficients:
#                 Estimate Std. Error t value Pr(>|t|)
# (Intercept)      3.15844    3.78965   0.833 0.405667
# female          -1.24630    1.07051  -1.164 0.245832
# factor(race)2   -1.06641    2.58737  -0.412 0.680697
# factor(race)3    0.59706    2.06030   0.290 0.772298
# factor(race)4    0.67935    1.58327   0.429 0.668362
# factor(ses)2    -0.34112    1.31163  -0.260 0.795097
# factor(ses)3     0.31544    1.48275   0.213 0.831762
# factor(schtyp)2 -0.28479    1.35643  -0.210 0.833934
# factor(prog)2    1.98252    1.32384   1.498 0.135946
# factor(prog)3    0.81048    1.45896   0.556 0.579207
# science          0.26176    0.07257   3.607 0.000398 ***
# math             0.26638    0.07820   3.406 0.000807 ***
# socst            0.24703    0.06200   3.984 9.71e-05 ***
# write            0.14379    0.08089   1.778 0.077113 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 6.706 on 186 degrees of freedom
# Multiple R-squared:  0.6002,	Adjusted R-squared:  0.5722
# F-statistic: 21.48 on 13 and 186 DF,  p-value: < 2.2e-16

# %%
fit1 <- lm(write ~  female + math, data=dataFrame)
summary(fit1)
# Out:
# Call:
# lm(formula = write ~ female + math, data = dataFrame)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -21.6871  -3.5126   0.2081   4.8060  18.0087
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 16.61374    2.90896   5.711 4.09e-08 ***
# female       5.21838    0.99751   5.231 4.28e-07 ***
# math         0.63287    0.05315  11.906  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 7.022 on 197 degrees of freedom
# Multiple R-squared:  0.4567,	Adjusted R-squared:  0.4512
# F-statistic: 82.81 on 2 and 197 DF,  p-value: < 2.2e-16

# %%
coef(fit1)
# Out:
# (Intercept)      female        math
#  16.6137389   5.2183771   0.6328663

# %%
library(ggplot2)

# %%
ggplot(dataFrame, aes(y = write, x = math)) + 
  geom_point(aes(col = as.factor(female))) +
  scale_color_manual(values = c("#E41A1C", "#4DAF4A")) +
  geom_abline(slope=coef(fit1)[3], intercept=coef(fit1)[1], col="#E41A1C") +
  geom_abline(slope=coef(fit1)[3], intercept=coef(fit1)[2]+coef(fit1)[1], col="#4DAF4A")
# Out:
# plot without title

# %%
fit1 <- lm(write ~  math, data=dataFrame)
summary(fit1)
rss_r  = sum(fit1$residuals^2)
# Out:
# Call:
# lm(formula = write ~ math, data = dataFrame)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -24.4956  -4.5277   0.3797   5.3785  16.4997
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 19.88724    3.02411   6.576  4.2e-10 ***
# math         0.62471    0.05656  11.045  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 7.475 on 198 degrees of freedom
# Multiple R-squared:  0.3812,	Adjusted R-squared:  0.3781
# F-statistic:   122 on 1 and 198 DF,  p-value: < 2.2e-16

# %%
fit1 <- lm(write ~  female + math + I(female*math), data=dataFrame)
summary(fit1)
# Out:
# Call:
# lm(formula = write ~ female + math + I(female * math), data = dataFrame)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -21.8310  -3.5547   0.2467   4.8463  18.1841
#
# Coefficients:
#                  Estimate Std. Error t value Pr(>|t|)
# (Intercept)      14.73524    4.12716   3.570 0.000448 ***
# female            8.82484    5.70070   1.548 0.123229
# math              0.66835    0.07670   8.714 1.23e-15 ***
# I(female * math) -0.06846    0.10654  -0.643 0.521249
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 7.032 on 196 degrees of freedom
# Multiple R-squared:  0.4579,	Adjusted R-squared:  0.4496
# F-statistic: 55.18 on 3 and 196 DF,  p-value: < 2.2e-16

# %%
fit1 <- lm(write ~  female + female*math, data=dataFrame)
summary(fit1)

rss_ur  = sum(fit1$residuals^2)
# Out:
# Call:
# lm(formula = write ~ female + female * math, data = dataFrame)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -21.8310  -3.5547   0.2467   4.8463  18.1841
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 14.73524    4.12716   3.570 0.000448 ***
# female       8.82484    5.70070   1.548 0.123229
# math         0.66835    0.07670   8.714 1.23e-15 ***
# female:math -0.06846    0.10654  -0.643 0.521249
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 7.032 on 196 degrees of freedom
# Multiple R-squared:  0.4579,	Adjusted R-squared:  0.4496
# F-statistic: 55.18 on 3 and 196 DF,  p-value: < 2.2e-16

# %%
coef(fit1)
# Out:
# (Intercept)      female        math female:math
# 14.73524337  8.82483778  0.66834638 -0.06845999

# %%
ggplot(dataFrame, aes(x = math, y = write)) + 
  geom_point(aes(col = as.factor(female))) +
  scale_color_manual(values = c("#E41A1C","#4DAF4A")) +
  geom_abline(slope=coef(fit1)[3], intercept=coef(fit1)[1], col="#4DAF4A") +
  geom_abline(slope=coef(fit1)[3]+coef(fit1)[4], intercept=coef(fit1)[2]+coef(fit1)[1], col="#E41A1C")
# Out:
# plot without title

# %%
ggplot(dataFrame, aes(y = write, x = math)) + 
  geom_point(aes(col = as.factor(female))) +
  scale_color_manual(values = c("#E41A1C","#4DAF4A")) +
  geom_smooth(aes(col=as.factor(female)))
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
ggplot(dataFrame, aes(y = write, x = math)) + 
  geom_point(aes(col = as.factor(female))) +
  scale_color_manual(values = c("#E41A1C","#4DAF4A")) +
  geom_smooth(method="lm", aes(col=as.factor(female)))
# Out:
# `geom_smooth()` using formula 'y ~ x'
# plot without title

# %%
coef(fit1)
# Out:
# (Intercept)      female        math female:math
# 14.73524337  8.82483778  0.66834638 -0.06845999

# %%
library(car)
# Out:
# Loading required package: carData

# %%
linearHypothesis(fit1, c("female", "female:math"))
# Out:
#   Res.Df RSS       Df Sum of Sq F        Pr(>F)
# 1 198    11062.668 NA       NA        NA           NA
# 2 196     9692.867  2 1369.801  13.84942 2.366197e-06

# %%
rss_r
rss_ur
# Out:
# [1] 11062.67
# [1] 9692.867

# %%
((rss_r-rss_ur)/2)/(rss_ur/196)
# Out:
# [1] 13.84942

# %%
fit1_woman <- lm(write ~  math, data=dataFrame[dataFrame['female']==1,])
summary(fit1_woman)

rss_w =   sum(fit1_woman$residuals^2)
# Out:
# Call:
# lm(formula = write ~ math, data = dataFrame[dataFrame["female"] ==
#     1, ])
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -16.7536  -3.3546   0.6465   4.2458  13.8446
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  23.5601     3.3719   6.987 2.49e-10 ***
# math          0.5999     0.0634   9.461 8.47e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 6.03 on 107 degrees of freedom
# Multiple R-squared:  0.4555,	Adjusted R-squared:  0.4504
# F-statistic: 89.51 on 1 and 107 DF,  p-value: 8.468e-16

# %%
fit1_man <- lm(write ~  math, data=dataFrame[dataFrame['female']==0,])
summary(fit1_man)

rss_m =   sum(fit1_man$residuals^2)
# Out:
# Call:
# lm(formula = write ~ math, data = dataFrame[dataFrame["female"] ==
#     0, ])
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -21.8310  -5.3259  -0.4691   5.5032  18.1841
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 14.73524    4.73877   3.110  0.00252 **
# math         0.66835    0.08806   7.589    3e-11 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 8.074 on 89 degrees of freedom
# Multiple R-squared:  0.3929,	Adjusted R-squared:  0.3861
# F-statistic:  57.6 on 1 and 89 DF,  p-value: 2.999e-11

# %%
library(strucchange)
# Out:
# Loading required package: sandwich

# %%
linearHypothesis(fit1, c("female", "female:math"))
# Out:
#   Res.Df RSS       Df Sum of Sq F        Pr(>F)
# 1 198    11062.668 NA       NA        NA           NA
# 2 196     9692.867  2 1369.801  13.84942 2.366197e-06

# %%
## Sort the data
sort.of = dataFrame[order(dataFrame$math) , ]
head(sort.of)
# Out:
#     id  female race ses schtyp prog read write math science socst Dum1 Dum2
# 139   2 1      1    2   1      3    39   41    33   42      41    0    0
# 21  167 0      4    2   1      1    63   49    35   66      41    0    0
# 116 106 1      4    2   1      3    36   44    37   42      41    0    0
# 52  128 0      4    3   1      2    39   33    38   47      41    0    0
# 197 145 1      4    2   1      3    42   46    38   36      46    0    0
# 47   49 0      3    3   1      3    50   40    39   49      47    0    1
#     Dum3
# 139 0
# 21  1
# 116 1
# 52  1
# 197 1
# 47  0

# %%
((rss_r-rss_m-rss_w)/2)/((rss_m+rss_w)/196)
# Out:
# [1] 13.84942

# %%
sctest(dataFrame$write ~ dataFrame$math, type = "Chow")
# Out:
# 	Chow test
#
# data:  dataFrame$write ~ dataFrame$math
# F = 14.164, p-value = 1.797e-06

# %%
sort.of = cbind(index(dataFrame),dataFrame)
sctest(write ~ female+female*math, type = "Chow", data = sort.of)    
# points = floor(n*0.5)
# Out:
# 	Chow test
#
# data:  write ~ female + female * math
# F = 0.38653, p-value = 0.8181
