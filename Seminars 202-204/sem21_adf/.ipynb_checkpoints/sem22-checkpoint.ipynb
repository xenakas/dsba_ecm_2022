# %%
library(hexView)

# %%
data <- readEViews('EXPEND.WF1')
# Out:
# Warning message in readEViews("EXPEND.WF1"):
# “Skipping boilerplate variable
# ”
# Warning message in readEViews("EXPEND.WF1"):
# “Skipping boilerplate variable
# ”

# %%
y <- ts(data['COSM'], start=1990, frequency = 4)
x <- ts(data['DPI'], start=1990, frequency = 4)

# %%
library(forecast)
# Out:
# Registered S3 method overwritten by 'quantmod':
#   method            from
#   as.zoo.data.frame zoo

# %%
length(x)
# Out:
# [1] 25

# %%
ggtsdisplay(x)
# Out:
# plot without title

# %%
library(aTSA)
# Out:
# Attaching package: ‘aTSA’
#
#
# The following object is masked from ‘package:forecast’:
#
#     forecast
#
#
# The following object is masked from ‘package:graphics’:
#
#     identify

# %%
adf.test(x, 2)
# Out:
# Augmented Dickey-Fuller Test
# alternative: stationary
#
# Type 1: no drift no trend
#      lag   ADF p.value
# [1,]   0 2.990   0.990
# [2,]   1 0.821   0.872
# Type 2: with drift no trend
#      lag   ADF p.value
# [1,]   0 -3.60  0.0153
# [2,]   1 -2.33  0.2130
# Type 3: with drift and trend
#      lag    ADF p.value
# [1,]   0 -0.475   0.976
# [2,]   1 -1.050   0.914
# ----
# Note: in fact, p.value = 0.01 means p.value <= 0.01

# %%
ggtsdisplay(diff(x))
# Out:
# plot without title

# %%
adf.test(diff(x), 2)
# Out:
# Augmented Dickey-Fuller Test
# alternative: stationary
#
# Type 1: no drift no trend
#      lag   ADF p.value
# [1,]   0 -2.06   0.041
# [2,]   1 -2.12   0.036
# Type 2: with drift no trend
#      lag   ADF p.value
# [1,]   0 -2.49  0.1540
# [2,]   1 -2.87  0.0668
# Type 3: with drift and trend
#      lag   ADF p.value
# [1,]   0 -3.35  0.0847
# [2,]   1 -4.40  0.0100
# ----
# Note: in fact, p.value = 0.01 means p.value <= 0.01

# %%
t <- 1:length(x)
mod<-lm(x~t)
summary(mod)
# Out:
# Call:
# lm(formula = x ~ t)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1.04308 -0.41323 -0.02369  0.59123  0.90615
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  3.77000    0.23745   15.88 6.91e-14 ***
# t            0.21492    0.01597   13.46 2.18e-12 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.5759 on 23 degrees of freedom
# Multiple R-squared:  0.8873,	Adjusted R-squared:  0.8824
# F-statistic: 181.1 on 1 and 23 DF,  p-value: 2.177e-12

# %%
ggtsdisplay(mod$residuals)
# Out:
# plot without title

# %%
adf.test(mod$residuals, 2)
# Out:
# Augmented Dickey-Fuller Test
# alternative: stationary
#
# Type 1: no drift no trend
#      lag    ADF p.value
# [1,]   0 -0.851   0.365
# [2,]   1 -1.442   0.156
# Type 2: with drift no trend
#      lag    ADF p.value
# [1,]   0 -0.824   0.743
# [2,]   1 -1.364   0.557
# Type 3: with drift and trend
#      lag    ADF p.value
# [1,]   0 -0.475   0.976
# [2,]   1 -1.050   0.914
# ----
# Note: in fact, p.value = 0.01 means p.value <= 0.01
